# %% [markdown]
# Amy Williams	Seller	Italian mafiosi, sells several central houses(top10%) over time, needs average outskirt houses over time to hide from the FBI.
#
# for this customer we should find the house in the outskirt for hidding. Maybe in the poor neighborhood or one country house.
# - No waterfront house (?) why not? It should be in a calm neighborhood
# - No central house
# - Not too big house
# - Big lotsquare
# - Less bedrooms
# - Less bathromms
# - only one floor
# - with the basement
# - price in the middle segment
#
# Mehr konkretes werden. find some question, that are true or not true. Versuchen etwas im Mittleren Segment zu finden. Es sollte nicht zu ausgefallen sein.
#
# Hypothesis:
# - The house with big lotsquare, basement and calm neighborhood. Price should be in the middle segment.
# - The country house with the good neighborgood, who care about the strange people on the street. This house can belong to the other person, because this is only for hidding.
#
#
# Exculse from the list:
# - the houses without basement
# - the houses with very good or very bad grade
# - the houses with more as 2 bedrooms
# - the houses with more as 1 bathrooms
# - the houses with too high or too low prices

# %%
import warnings

warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


from matplotlib.ticker import PercentFormatter
plt.rcParams.update({ "figure.figsize" : (8, 5),"axes.facecolor" : "white", "axes.edgecolor":  "black"})
plt.rcParams["figure.facecolor"]= "w"
pd.plotting.register_matplotlib_converters()
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
df_GF = pd.read_csv('data/King_County_House_prices_dataset.csv')
df_GF
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014 221900.000         3      1.000         1180
# 1      6414100192   12/9/2014 538000.000         3      2.250         2570
# 2      5631500400   2/25/2015 180000.000         2      1.000          770
# 3      2487200875   12/9/2014 604000.000         4      3.000         1960
# 4      1954400510   2/18/2015 510000.000         3      2.000         1680
# ...           ...         ...        ...       ...        ...          ...
# 21592   263000018   5/21/2014 360000.000         3      2.500         1530
# 21593  6600060120   2/23/2015 400000.000         4      2.500         2310
# 21594  1523300141   6/23/2014 402101.000         2      0.750         1020
# 21595   291310100   1/16/2015 400000.000         3      2.500         1600
# 21596  1523300157  10/15/2014 325000.000         2      0.750         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
df_GF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  float64
#  9   view           21534 non-null  float64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  object
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   17755 non-null  float64
#  16  zipcode        21597 non-null  int64
# ...

# %%
df_GF.shape
# Out:
# (21597, 21)

# %%
df_GF.describe()
# Out:
#                   id       price  bedrooms  bathrooms  sqft_living  \
# count      21597.000   21597.000 21597.000  21597.000    21597.000
# mean  4580474287.771  540296.574     3.373      2.116     2080.322
# std   2876735715.748  367368.140     0.926      0.769      918.106
# min      1000102.000   78000.000     1.000      0.500      370.000
# 25%   2123049175.000  322000.000     3.000      1.750     1430.000
# 50%   3904930410.000  450000.000     3.000      2.250     1910.000
# 75%   7308900490.000  645000.000     4.000      2.500     2550.000
# max   9900000190.000 7700000.000    33.000      8.000    13540.000
#
#          sqft_lot    floors  waterfront      view  condition     grade  \
# count   21597.000 21597.000   19221.000 21534.000  21597.000 21597.000
# mean    15099.409     1.494       0.008     0.234      3.410     7.658
# std     41412.637     0.540       0.087     0.766      0.651     1.173
# min       520.000     1.000       0.000     0.000      1.000     3.000
# ...

# %%
df_GF['bathrooms'].unique()
# Out:
# array([1.  , 2.25, 3.  , 2.  , 4.5 , 1.5 , 2.5 , 1.75, 2.75, 3.25, 4.  ,
#        3.5 , 0.75, 4.75, 5.  , 4.25, 3.75, 1.25, 5.25, 6.  , 0.5 , 5.5 ,
#        6.75, 5.75, 8.  , 7.5 , 7.75, 6.25, 6.5 ])

# %%
df_GF['bathrooms'].nunique()
# Out:
# 29

# %%
#zählt die häuser anhang der Anzahl der Schlafzimmer
df_GF['bedrooms'].value_counts()
# Out:
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      196
# 7       38
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
df_GF['bathrooms'].value_counts()
# Out:
# 2.500    5377
# 1.000    3851
# 1.750    3048
# 2.250    2047
# 2.000    1930
# 1.500    1445
# 2.750    1185
# 3.000     753
# 3.500     731
# 3.250     589
# 3.750     155
# 4.000     136
# 4.500     100
# 4.250      79
# 0.750      71
# 4.750      23
# 5.000      21
# 5.250      13
# 5.500      10
# 1.250       9
# 6.000       6
# 0.500       4
# 5.750       4
# 6.750       2
# 8.000       2
# 6.250       2
# 6.500       2
# 7.500       1
# 7.750       1
# Name: bathrooms, dtype: int64
